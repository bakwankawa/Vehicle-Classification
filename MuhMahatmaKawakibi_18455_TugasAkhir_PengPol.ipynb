# %%
pip install scipy==1.1.0

# %%
from matplotlib import pyplot
from scipy.misc import toimage
from PIL import Image
from keras.datasets import cifar10
def show_imgs(X):
    pyplot.figure(1)
    k = 0
    for i in range(0,4):
        for j in range(0,4):
            pyplot.subplot2grid((4,4),(i,j))
            pyplot.imshow(toimage(X[k]))
            k = k+1
    # show the plot
    pyplot.show()
 
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
show_imgs(x_test[:16])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: DeprecationWarning:     `toimage` is deprecated!
#     `toimage` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use Pillow's ``Image.fromarray`` directly instead.
#   # This is added back by InteractiveShellApp.init_path()

# %%
from keras.preprocessing.image import ImageDataGenerator
datagen = ImageDataGenerator( rotation_range=90,
                 width_shift_range=0.1, height_shift_range=0.1,
                 horizontal_flip=True)
datagen.fit(x_train)

# %%
from matplotlib import pyplot as plt
# Configure batch size and retrieve one batch of images
for X_batch, y_batch in datagen.flow(x_train, y_train, batch_size=9):
    # Show 9 images
    for i in range(0, 9):
        plt.subplot(330 + 1 + i)
        plt.imshow(toimage(X_batch[i].reshape(32, 32, 3)))
    # show the plot
    plt.show()
    break
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: DeprecationWarning:     `toimage` is deprecated!
#     `toimage` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use Pillow's ``Image.fromarray`` directly instead.
#   import sys

# %%
import keras
from keras.models import Sequential
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization
from keras.layers import Conv2D, MaxPooling2D
from keras.datasets import cifar10
from keras import regularizers
from keras.callbacks import LearningRateScheduler
import numpy as np
 
def lr_schedule(epoch):
    lrate = 0.001
    if epoch > 75:
        lrate = 0.0005
    if epoch > 100:
        lrate = 0.0003
    return lrate

(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

#z-score
mean = np.mean(x_train,axis=(0,1,2,3))
std = np.std(x_train,axis=(0,1,2,3))
x_train = (x_train-mean)/(std+1e-7)
x_test = (x_test-mean)/(std+1e-7)

num_classes = 10
y_train = np_utils.to_categorical(y_train,num_classes)
y_test = np_utils.to_categorical(y_test,num_classes)

weight_decay = 1e-4
model = Sequential()
model.add(Conv2D(32, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay), input_shape=x_train.shape[1:]))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(32, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))
 
model.add(Conv2D(64, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(64, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.3))

model.add(Conv2D(128, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(128, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))
 
model.add(Flatten())
model.add(Dense(num_classes, activation='softmax'))
 
model.summary()

#data augmentation
datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    )
datagen.fit(x_train)
 
#training
batch_size = 64
 
opt_rms = keras.optimizers.RMSprop(lr=0.001,decay=1e-6)
model.compile(loss='categorical_crossentropy', optimizer=opt_rms, metrics=['accuracy'])
model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),\
                    steps_per_epoch=x_train.shape[0] // batch_size,epochs=125,\
                    verbose=1,validation_data=(x_test,y_test),callbacks=[LearningRateScheduler(lr_schedule)])

#save to disk
model_json = model.to_json()
with open('model.json', 'w') as json_file:
    json_file.write(model_json)
model.save_weights('model.h5') 

#testing
scores = model.evaluate(x_test, y_test, batch_size=128, verbose=1)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# activation_6 (Activation)    (None, 32, 32, 32)        0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# activation_7 (Activation)    (None, 32, 32, 32)        0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# activation_8 (Activation)    (None, 16, 16, 64)        0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# activation_9 (Activation)    (None, 16, 16, 64)        0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 8, 8, 128)         73856
# _________________________________________________________________
# activation_10 (Activation)   (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 8, 8, 128)         512
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 8, 8, 128)         147584
# _________________________________________________________________
# activation_11 (Activation)   (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 8, 8, 128)         512
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                20490
# =================================================================
# Total params: 309,290
# Trainable params: 308,394
# Non-trainable params: 896
# _________________________________________________________________
# Epoch 1/125
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1915: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# 781/781 [==============================] - 30s 36ms/step - loss: 2.3429 - accuracy: 0.3443 - val_loss: 1.5046 - val_accuracy: 0.5642
# Epoch 2/125
# 781/781 [==============================] - 27s 35ms/step - loss: 1.3221 - accuracy: 0.5747 - val_loss: 1.3568 - val_accuracy: 0.6140
# Epoch 3/125
# 781/781 [==============================] - 27s 35ms/step - loss: 1.0999 - accuracy: 0.6433 - val_loss: 0.9157 - val_accuracy: 0.7177
# Epoch 4/125
# 781/781 [==============================] - 27s 35ms/step - loss: 0.9962 - accuracy: 0.6834 - val_loss: 0.8629 - val_accuracy: 0.7352
# Epoch 5/125
# 781/781 [==============================] - 27s 35ms/step - loss: 0.9150 - accuracy: 0.7110 - val_loss: 0.8744 - val_accuracy: 0.7400
# Epoch 6/125
# 781/781 [==============================] - 27s 35ms/step - loss: 0.8626 - accuracy: 0.7323 - val_loss: 0.8793 - val_accuracy: 0.7475
# Epoch 7/125
# 781/781 [==============================] - 27s 35ms/step - loss: 0.8394 - accuracy: 0.7428 - val_loss: 0.7411 - val_accuracy: 0.7888
# Epoch 8/125
# 781/781 [==============================] - 27s 35ms/step - loss: 0.8001 - accuracy: 0.7599 - val_loss: 0.7800 - val_accuracy: 0.7785
# Epoch 9/125
# 781/781 [==============================] - 27s 35ms/step - loss: 0.7648 - accuracy: 0.7755 - val_loss: 0.6665 - val_accuracy: 0.8179
# Epoch 10/125
# 781/781 [==============================] - 27s 35ms/step - loss: 0.7551 - accuracy: 0.7764 - val_loss: 0.7051 - val_accuracy: 0.8038
# Epoch 11/125
# 781/781 [==============================] - 27s 35ms/step - loss: 0.7296 - accuracy: 0.7878 - val_loss: 0.7438 - val_accuracy: 0.7969
# Epoch 12/125
# 781/781 [==============================] - 27s 35ms/step - loss: 0.7315 - accuracy: 0.7905 - val_loss: 0.7423 - val_accuracy: 0.7972
# Epoch 13/125
# 781/781 [==============================] - 27s 35ms/step - loss: 0.7073 - accuracy: 0.7999 - val_loss: 0.7023 - val_accuracy: 0.8102
# Epoch 14/125
# 781/781 [==============================] - 27s 34ms/step - loss: 0.7120 - accuracy: 0.7957 - val_loss: 0.6344 - val_accuracy: 0.8296
# Epoch 15/125
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6893 - accuracy: 0.8057 - val_loss: 0.6282 - val_accuracy: 0.8311
# Epoch 16/125
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6831 - accuracy: 0.8100 - val_loss: 0.6445 - val_accuracy: 0.8269
# Epoch 17/125
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6786 - accuracy: 0.8128 - val_loss: 0.6152 - val_accuracy: 0.8404
# Epoch 18/125
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6670 - accuracy: 0.8150 - val_loss: 0.6677 - val_accuracy: 0.8207
# Epoch 19/125
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6674 - accuracy: 0.8155 - val_loss: 0.6746 - val_accuracy: 0.8233
# Epoch 20/125
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6634 - accuracy: 0.8183 - val_loss: 0.6088 - val_accuracy: 0.8418
# Epoch 21/125
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6517 - accuracy: 0.8229 - val_loss: 0.6627 - val_accuracy: 0.8237
# Epoch 22/125
# 781/781 [==============================] - 27s 35ms/step - loss: 0.6520 - accuracy: 0.8241 - val_loss: 0.6617 - val_accuracy: 0.8249
# Epoch 23/125
# 781/781 [==============================] - 28s 35ms/step - loss: 0.6458 - accuracy: 0.8244 - val_loss: 0.5790 - val_accuracy: 0.8526
# Epoch 24/125
# 781/781 [==============================] - 28s 36ms/step - loss: 0.6465 - accuracy: 0.8228 - val_loss: 0.6007 - val_accuracy: 0.8447
# Epoch 25/125
# 781/781 [==============================] - 27s 35ms/step - loss: 0.6266 - accuracy: 0.8337 - val_loss: 0.6024 - val_accuracy: 0.8445
# Epoch 26/125
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6299 - accuracy: 0.8283 - val_loss: 0.6974 - val_accuracy: 0.8185
# Epoch 27/125
# 781/781 [==============================] - 27s 35ms/step - loss: 0.6378 - accuracy: 0.8301 - val_loss: 0.6014 - val_accuracy: 0.8468
# Epoch 28/125
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6323 - accuracy: 0.8317 - val_loss: 0.6339 - val_accuracy: 0.8362
# Epoch 29/125
# 781/781 [==============================] - 27s 35ms/step - loss: 0.6180 - accuracy: 0.8363 - val_loss: 0.5899 - val_accuracy: 0.8491
# Epoch 30/125
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6200 - accuracy: 0.8352 - val_loss: 0.6846 - val_accuracy: 0.8293
# Epoch 31/125
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6191 - accuracy: 0.8363 - val_loss: 0.6877 - val_accuracy: 0.8285
# Epoch 32/125
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6185 - accuracy: 0.8386 - val_loss: 0.5957 - val_accuracy: 0.8543
# Epoch 33/125
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6121 - accuracy: 0.8389 - val_loss: 0.6185 - val_accuracy: 0.8433
# Epoch 34/125
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6175 - accuracy: 0.8359 - val_loss: 0.5740 - val_accuracy: 0.8586
# Epoch 35/125
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6086 - accuracy: 0.8406 - val_loss: 0.6324 - val_accuracy: 0.8437
# Epoch 36/125
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6032 - accuracy: 0.8425 - val_loss: 0.6490 - val_accuracy: 0.8360
# Epoch 37/125
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6093 - accuracy: 0.8429 - val_loss: 0.6162 - val_accuracy: 0.8481
# Epoch 38/125
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6045 - accuracy: 0.8422 - val_loss: 0.6513 - val_accuracy: 0.8433
# Epoch 39/125
# 781/781 [==============================] - 27s 35ms/step - loss: 0.6075 - accuracy: 0.8407 - val_loss: 0.6222 - val_accuracy: 0.8413
# Epoch 40/125
# 781/781 [==============================] - 27s 35ms/step - loss: 0.6065 - accuracy: 0.8430 - val_loss: 0.5653 - val_accuracy: 0.8611
# Epoch 41/125
# 781/781 [==============================] - 27s 35ms/step - loss: 0.5991 - accuracy: 0.8447 - val_loss: 0.5750 - val_accuracy: 0.8601
# Epoch 42/125
# 781/781 [==============================] - 27s 34ms/step - loss: 0.5976 - accuracy: 0.8455 - val_loss: 0.6201 - val_accuracy: 0.8457
# Epoch 43/125
# 781/781 [==============================] - 27s 34ms/step - loss: 0.5993 - accuracy: 0.8447 - val_loss: 0.6019 - val_accuracy: 0.8537
# Epoch 44/125
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6006 - accuracy: 0.8468 - val_loss: 0.6123 - val_accuracy: 0.8509
# Epoch 45/125
# 781/781 [==============================] - 27s 34ms/step - loss: 0.5978 - accuracy: 0.8472 - val_loss: 0.6785 - val_accuracy: 0.8300
# Epoch 46/125
# 781/781 [==============================] - 27s 34ms/step - loss: 0.5938 - accuracy: 0.8466 - val_loss: 0.6249 - val_accuracy: 0.8428
# Epoch 47/125
# 781/781 [==============================] - 27s 35ms/step - loss: 0.5959 - accuracy: 0.8470 - val_loss: 0.6658 - val_accuracy: 0.8313
# Epoch 48/125
# 781/781 [==============================] - 27s 35ms/step - loss: 0.5956 - accuracy: 0.8469 - val_loss: 0.5618 - val_accuracy: 0.8602
# Epoch 49/125
# 781/781 [==============================] - 27s 34ms/step - loss: 0.6003 - accuracy: 0.8440 - val_loss: 0.6095 - val_accuracy: 0.8517
# Epoch 50/125
# 781/781 [==============================] - 27s 34ms/step - loss: 0.5902 - accuracy: 0.8494 - val_loss: 0.5471 - val_accuracy: 0.8689
# Epoch 51/125
# 781/781 [==============================] - 27s 34ms/step - loss: 0.5865 - accuracy: 0.8513 - val_loss: 0.6161 - val_accuracy: 0.8486
# Epoch 52/125
# 781/781 [==============================] - 27s 34ms/step - loss: 0.5928 - accuracy: 0.8470 - val_loss: 0.6165 - val_accuracy: 0.8475
# Epoch 53/125
# 781/781 [==============================] - 27s 34ms/step - loss: 0.5822 - accuracy: 0.8503 - val_loss: 0.5779 - val_accuracy: 0.8585
# Epoch 54/125
# 781/781 [==============================] - 27s 34ms/step - loss: 0.5869 - accuracy: 0.8487 - val_loss: 0.6216 - val_accuracy: 0.8520
# Epoch 55/125
# 781/781 [==============================] - 27s 34ms/step - loss: 0.5847 - accuracy: 0.8525 - val_loss: 0.6050 - val_accuracy: 0.8576
# Epoch 56/125
# 781/781 [==============================] - 27s 34ms/step - loss: 0.5806 - accuracy: 0.8525 - val_loss: 0.5851 - val_accuracy: 0.8622
# Epoch 57/125
# 781/781 [==============================] - 27s 34ms/step - loss: 0.5868 - accuracy: 0.8516 - val_loss: 0.5997 - val_accuracy: 0.8520
# Epoch 58/125
# 781/781 [==============================] - 27s 35ms/step - loss: 0.5801 - accuracy: 0.8536 - val_loss: 0.6965 - val_accuracy: 0.8337
# Epoch 59/125
# 781/781 [==============================] - 27s 35ms/step - loss: 0.5788 - accuracy: 0.8507 - val_loss: 0.6325 - val_accuracy: 0.8457
# Epoch 60/125
# 781/781 [==============================] - 27s 35ms/step - loss: 0.5821 - accuracy: 0.8531 - val_loss: 0.6151 - val_accuracy: 0.8485
# Epoch 61/125
# 781/781 [==============================] - 27s 35ms/step - loss: 0.5785 - accuracy: 0.8560 - val_loss: 0.6058 - val_accuracy: 0.8522
# Epoch 62/125
# 781/781 [==============================] - 27s 34ms/step - loss: 0.5812 - accuracy: 0.8525 - val_loss: 0.6143 - val_accuracy: 0.8531
# Epoch 63/125
# 781/781 [==============================] - 27s 35ms/step - loss: 0.5738 - accuracy: 0.8567 - val_loss: 0.6642 - val_accuracy: 0.8363
# Epoch 64/125
# 781/781 [==============================] - 27s 34ms/step - loss: 0.5777 - accuracy: 0.8556 - val_loss: 0.5824 - val_accuracy: 0.8607
# Epoch 65/125
# 781/781 [==============================] - 27s 35ms/step - loss: 0.5705 - accuracy: 0.8541 - val_loss: 0.5710 - val_accuracy: 0.8645
# Epoch 66/125
# 781/781 [==============================] - 28s 36ms/step - loss: 0.5799 - accuracy: 0.8546 - val_loss: 0.5663 - val_accuracy: 0.8631
# Epoch 67/125
# 781/781 [==============================] - 28s 36ms/step - loss: 0.5761 - accuracy: 0.8557 - val_loss: 0.5670 - val_accuracy: 0.8656
# Epoch 68/125
# 781/781 [==============================] - 28s 35ms/step - loss: 0.5700 - accuracy: 0.8555 - val_loss: 0.5702 - val_accuracy: 0.8635
# Epoch 69/125
# 781/781 [==============================] - 27s 35ms/step - loss: 0.5664 - accuracy: 0.8578 - val_loss: 0.6093 - val_accuracy: 0.8472
# Epoch 70/125
# 781/781 [==============================] - 27s 35ms/step - loss: 0.5689 - accuracy: 0.8590 - val_loss: 0.5455 - val_accuracy: 0.8703
# Epoch 71/125
# 781/781 [==============================] - 28s 36ms/step - loss: 0.5754 - accuracy: 0.8539 - val_loss: 0.5437 - val_accuracy: 0.8724
# Epoch 72/125
# 781/781 [==============================] - 28s 36ms/step - loss: 0.5672 - accuracy: 0.8576 - val_loss: 0.5636 - val_accuracy: 0.8626
# Epoch 73/125
# 781/781 [==============================] - 28s 36ms/step - loss: 0.5759 - accuracy: 0.8554 - val_loss: 0.6805 - val_accuracy: 0.8361
# Epoch 74/125
# 781/781 [==============================] - 28s 36ms/step - loss: 0.5687 - accuracy: 0.8596 - val_loss: 0.5821 - val_accuracy: 0.8563
# Epoch 75/125
# 781/781 [==============================] - 28s 36ms/step - loss: 0.5752 - accuracy: 0.8571 - val_loss: 0.6023 - val_accuracy: 0.8576
# Epoch 76/125
# 781/781 [==============================] - 28s 36ms/step - loss: 0.5735 - accuracy: 0.8572 - val_loss: 0.6056 - val_accuracy: 0.8512
# Epoch 77/125
# 781/781 [==============================] - 28s 36ms/step - loss: 0.5431 - accuracy: 0.8658 - val_loss: 0.4979 - val_accuracy: 0.8837
# Epoch 78/125
# 781/781 [==============================] - 28s 36ms/step - loss: 0.5187 - accuracy: 0.8729 - val_loss: 0.5284 - val_accuracy: 0.8751
# Epoch 79/125
# 781/781 [==============================] - 28s 35ms/step - loss: 0.5041 - accuracy: 0.8763 - val_loss: 0.5623 - val_accuracy: 0.8697
# Epoch 80/125
# 781/781 [==============================] - 27s 35ms/step - loss: 0.4960 - accuracy: 0.8775 - val_loss: 0.5457 - val_accuracy: 0.8696
# Epoch 81/125
# 781/781 [==============================] - 27s 35ms/step - loss: 0.4918 - accuracy: 0.8778 - val_loss: 0.5258 - val_accuracy: 0.8775
# Epoch 82/125
# 781/781 [==============================] - 27s 35ms/step - loss: 0.4908 - accuracy: 0.8759 - val_loss: 0.5391 - val_accuracy: 0.8732
# Epoch 83/125
# 781/781 [==============================] - 27s 35ms/step - loss: 0.4762 - accuracy: 0.8804 - val_loss: 0.5403 - val_accuracy: 0.8709
# Epoch 84/125
# 781/781 [==============================] - 27s 35ms/step - loss: 0.4704 - accuracy: 0.8827 - val_loss: 0.4889 - val_accuracy: 0.8811
# Epoch 85/125
# 781/781 [==============================] - 27s 35ms/step - loss: 0.4701 - accuracy: 0.8846 - val_loss: 0.5348 - val_accuracy: 0.8726
# Epoch 86/125
# 781/781 [==============================] - 28s 35ms/step - loss: 0.4845 - accuracy: 0.8763 - val_loss: 0.5107 - val_accuracy: 0.8762
# Epoch 87/125
# 781/781 [==============================] - 27s 35ms/step - loss: 0.4755 - accuracy: 0.8814 - val_loss: 0.5258 - val_accuracy: 0.8725
# Epoch 88/125
# 781/781 [==============================] - 27s 35ms/step - loss: 0.4691 - accuracy: 0.8820 - val_loss: 0.4911 - val_accuracy: 0.8827
# Epoch 89/125
# 781/781 [==============================] - 28s 35ms/step - loss: 0.4801 - accuracy: 0.8792 - val_loss: 0.4694 - val_accuracy: 0.8888
# Epoch 90/125
# 781/781 [==============================] - 28s 35ms/step - loss: 0.4602 - accuracy: 0.8823 - val_loss: 0.4917 - val_accuracy: 0.8775
# Epoch 91/125
# 781/781 [==============================] - 28s 36ms/step - loss: 0.4638 - accuracy: 0.8828 - val_loss: 0.4970 - val_accuracy: 0.8798
# Epoch 92/125
# 781/781 [==============================] - 27s 35ms/step - loss: 0.4623 - accuracy: 0.8813 - val_loss: 0.4794 - val_accuracy: 0.8858
# Epoch 93/125
# 781/781 [==============================] - 27s 35ms/step - loss: 0.4579 - accuracy: 0.8847 - val_loss: 0.4956 - val_accuracy: 0.8790
# Epoch 94/125
# 781/781 [==============================] - 28s 35ms/step - loss: 0.4623 - accuracy: 0.8815 - val_loss: 0.4591 - val_accuracy: 0.8896
# Epoch 95/125
# 781/781 [==============================] - 27s 35ms/step - loss: 0.4586 - accuracy: 0.8832 - val_loss: 0.4737 - val_accuracy: 0.8856
# Epoch 96/125
# 781/781 [==============================] - 27s 35ms/step - loss: 0.4555 - accuracy: 0.8852 - val_loss: 0.5011 - val_accuracy: 0.8785
# Epoch 97/125
# 781/781 [==============================] - 27s 35ms/step - loss: 0.4583 - accuracy: 0.8849 - val_loss: 0.4884 - val_accuracy: 0.8833
# Epoch 98/125
# 781/781 [==============================] - 27s 35ms/step - loss: 0.4466 - accuracy: 0.8858 - val_loss: 0.5279 - val_accuracy: 0.8696
# Epoch 99/125
# 781/781 [==============================] - 28s 35ms/step - loss: 0.4541 - accuracy: 0.8816 - val_loss: 0.4886 - val_accuracy: 0.8814
# Epoch 100/125
# 781/781 [==============================] - 27s 35ms/step - loss: 0.4529 - accuracy: 0.8831 - val_loss: 0.4758 - val_accuracy: 0.8880
# Epoch 101/125
# 781/781 [==============================] - 27s 35ms/step - loss: 0.4530 - accuracy: 0.8854 - val_loss: 0.4947 - val_accuracy: 0.8758
# Epoch 102/125
# 781/781 [==============================] - 28s 36ms/step - loss: 0.4411 - accuracy: 0.8865 - val_loss: 0.4409 - val_accuracy: 0.8928
# Epoch 103/125
# 781/781 [==============================] - 27s 35ms/step - loss: 0.4223 - accuracy: 0.8939 - val_loss: 0.5400 - val_accuracy: 0.8706
# Epoch 104/125
# 781/781 [==============================] - 27s 35ms/step - loss: 0.4167 - accuracy: 0.8957 - val_loss: 0.5059 - val_accuracy: 0.8774
# Epoch 105/125
# 781/781 [==============================] - 27s 35ms/step - loss: 0.4089 - accuracy: 0.8971 - val_loss: 0.4579 - val_accuracy: 0.8902
# Epoch 106/125
# 781/781 [==============================] - 27s 35ms/step - loss: 0.4072 - accuracy: 0.8985 - val_loss: 0.4502 - val_accuracy: 0.8908
# Epoch 107/125
# 781/781 [==============================] - 27s 35ms/step - loss: 0.4166 - accuracy: 0.8937 - val_loss: 0.4763 - val_accuracy: 0.8877
# Epoch 108/125
# 781/781 [==============================] - 28s 35ms/step - loss: 0.4055 - accuracy: 0.8965 - val_loss: 0.4523 - val_accuracy: 0.8896
# Epoch 109/125
# 781/781 [==============================] - 28s 35ms/step - loss: 0.4077 - accuracy: 0.8975 - val_loss: 0.4705 - val_accuracy: 0.8854
# Epoch 110/125
# 781/781 [==============================] - 28s 36ms/step - loss: 0.4029 - accuracy: 0.8982 - val_loss: 0.4754 - val_accuracy: 0.8799
# Epoch 111/125
# 781/781 [==============================] - 27s 35ms/step - loss: 0.4009 - accuracy: 0.8981 - val_loss: 0.4419 - val_accuracy: 0.8907
# Epoch 112/125
# 781/781 [==============================] - 27s 35ms/step - loss: 0.4017 - accuracy: 0.8974 - val_loss: 0.4554 - val_accuracy: 0.8891
# Epoch 113/125
# 781/781 [==============================] - 27s 35ms/step - loss: 0.4002 - accuracy: 0.8989 - val_loss: 0.4623 - val_accuracy: 0.8861
# Epoch 114/125
# 781/781 [==============================] - 27s 35ms/step - loss: 0.4005 - accuracy: 0.8951 - val_loss: 0.4544 - val_accuracy: 0.8886
# Epoch 115/125
# 781/781 [==============================] - 27s 35ms/step - loss: 0.3941 - accuracy: 0.9000 - val_loss: 0.4452 - val_accuracy: 0.8896
# Epoch 116/125
# 781/781 [==============================] - 27s 35ms/step - loss: 0.3945 - accuracy: 0.9004 - val_loss: 0.4430 - val_accuracy: 0.8910
# Epoch 117/125
# 781/781 [==============================] - 27s 35ms/step - loss: 0.4009 - accuracy: 0.8970 - val_loss: 0.4757 - val_accuracy: 0.8825
# Epoch 118/125
# 781/781 [==============================] - 28s 35ms/step - loss: 0.3968 - accuracy: 0.8964 - val_loss: 0.4588 - val_accuracy: 0.8884
# Epoch 119/125
# 781/781 [==============================] - 27s 35ms/step - loss: 0.3965 - accuracy: 0.8971 - val_loss: 0.4472 - val_accuracy: 0.8898
# Epoch 120/125
# 781/781 [==============================] - 27s 35ms/step - loss: 0.3928 - accuracy: 0.8995 - val_loss: 0.4355 - val_accuracy: 0.8894
# Epoch 121/125
# 781/781 [==============================] - 27s 35ms/step - loss: 0.3930 - accuracy: 0.8993 - val_loss: 0.4664 - val_accuracy: 0.8871
# Epoch 122/125
# 781/781 [==============================] - 27s 35ms/step - loss: 0.3948 - accuracy: 0.8958 - val_loss: 0.4511 - val_accuracy: 0.8867
# Epoch 123/125
# 781/781 [==============================] - 27s 35ms/step - loss: 0.3897 - accuracy: 0.8988 - val_loss: 0.4808 - val_accuracy: 0.8797
# Epoch 124/125
# 781/781 [==============================] - 27s 34ms/step - loss: 0.3878 - accuracy: 0.8985 - val_loss: 0.4327 - val_accuracy: 0.8912
# Epoch 125/125
# 781/781 [==============================] - 28s 35ms/step - loss: 0.3956 - accuracy: 0.8977 - val_loss: 0.4724 - val_accuracy: 0.8858
# 79/79 [==============================] - 1s 7ms/step - loss: 0.4724 - accuracy: 0.8858

# %%
from keras.models import model_from_json
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
 
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
 
# mean-std normalization
mean = np.mean(x_train,axis=(0,1,2,3))
std = np.std(x_train,axis=(0,1,2,3))
x_train = (x_train-mean)/(std+1e-7)
x_test = (x_test-mean)/(std+1e-7)
 
show_imgs(x_test[:16])
 
# Load trained CNN model
json_file = open('model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
model = model_from_json(loaded_model_json)
model.load_weights('model.h5')
 
labels =  ['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']
 
indices = np.argmax(model.predict(x_test[:16]),1)
print([labels[x] for x in indices])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: DeprecationWarning:     `toimage` is deprecated!
#     `toimage` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use Pillow's ``Image.fromarray`` directly instead.
#   # This is added back by InteractiveShellApp.init_path()
# ['cat', 'ship', 'ship', 'airplane', 'frog', 'frog', 'automobile', 'frog', 'cat', 'automobile', 'airplane', 'truck', 'dog', 'horse', 'truck', 'ship']
